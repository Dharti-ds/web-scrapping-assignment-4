# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import re
import warnings
warnings.filterwarnings("ignore")

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)
url="https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
time.sleep(3)
driver.maximize_window()

# %%
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %%
rank=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
for i in rank:
    Rank.append(i.text)

# %%
name=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
for i in name:
    Name.append(i.text)

# %%
artist=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
for i in artist:
    Artist.append(i.text)

# %%
views=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
for i in views:
    Views.append(i.text)

# %%
upload_date=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
for i in upload_date:
    Upload_date.append(i.text)

# %%
Youtube_viewed=pd.DataFrame({})
Youtube_viewed['Rank']=Rank
Youtube_viewed['Name']=Name
Youtube_viewed['Artist']=Artist
Youtube_viewed['Upload_date']=Upload_date
Youtube_viewed['Views']=Views
Youtube_viewed
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                          "Thinking Out Loud"[36]
# 18  19.                                     "Axel F"[37]
# 19  20.                             "Girls Like You"[38]
# 20  21.                                      "Faded"[39]
# 21  22.                                 "Dark Horse"[40]
# 22  23.                        "Baa Baa Black Sheep"[41]
# 23  24.                                 "Let Her Go"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Lean On"[44]
# 26  27.                                    "Perfect"[45]
# 27  28.                               "Shake It Off"[46]
# 28  29.           "Waka Waka (This Time for Africa)"[47]
# 29  30.                                   "Mi Gente"[48]
#
#                                          Artist        Upload_date  Views
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  10.77
# 1                                    Luis Fonsi   January 12, 2017   7.87
# 2                                   LooLoo Kids    October 8, 2016   6.37
# 3                                    Ed Sheeran   January 30, 2017   5.74
# 4                                   Wiz Khalifa      April 6, 2015   5.53
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018   5.42
# 6                                     ChuChu TV      March 6, 2014   4.66
# 7                                   Mark Ronson  November 19, 2014   4.59
# 8                                   Miroshka TV  February 27, 2018   4.58
# 9                                    Get Movies   January 31, 2012   4.50
# 10                                          Psy      July 15, 2012   4.44
# 11                   Cocomelon – Nursery Rhymes       May 24, 2018   4.11
# 12                                    El Chombo      April 5, 2018   3.95
# 13                                     Maroon 5   January 14, 2015   3.70
# 14                                   Katy Perry  September 5, 2013   3.60
# 15                                  OneRepublic       May 31, 2013   3.59
# 16                                Justin Bieber   October 22, 2015   3.55
# 17                                   Ed Sheeran    October 7, 2014   3.46
# 18                                   Crazy Frog      June 16, 2009   3.38
# 19                                     Maroon 5       May 31, 2018   3.30
# 20                                  Alan Walker   December 3, 2015   3.29
# 21                                   Katy Perry  February 20, 2014   3.28
# 22                   Cocomelon – Nursery Rhymes      June 25, 2018   3.26
# 23                                    Passenger      July 25, 2012   3.24
# 24                             Enrique Iglesias     April 11, 2014   3.22
# 25                                  Major Lazer     March 22, 2015   3.21
# 26                                   Ed Sheeran   November 9, 2017   3.18
# 27                                 Taylor Swift    August 18, 2014   3.18
# 28                                      Shakira       June 4, 2010   3.16
# 29                                     J Balvin      June 29, 2017   3.09
